# %%
signal = 0b11010110
ones = signal.bit_count()
parity = "Even Parity" if ones % 2 == 0 else "Odd Parity"

print("Number of 1s:", ones)
print("Parity Type:", parity)
# Out:
# Number of 1s: 5
# Parity Type: Odd Parity
