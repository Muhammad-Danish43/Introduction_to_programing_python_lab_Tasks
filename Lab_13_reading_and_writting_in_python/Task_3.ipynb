# %%
with open("maintenance_log.txt", "w") as file:
    file.write("Transformer Maintenance Log\n")
    file.write("----------------------------\n")
    file.write("Date: 2025-01-05 | Activity: Oil Check | Status: OK\n")
    file.write("Date: 2025-01-10 | Activity: Insulation Test | Status: Good\n")
    file.write("Date: 2025-01-15 | Activity: Cooling System | Status: Serviced\n")

print("Maintenance report created successfully.")
# Out:
# Maintenance report created successfully.
