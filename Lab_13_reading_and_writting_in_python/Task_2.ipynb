# %%
with open("solar_generation.csv", "w") as file:
    file.write("Date,Energy_kWh\n")
    file.write("2025-01-01,25\n")
    file.write("2025-01-02,30\n")

with open("solar_generation.csv", "a") as file:
    file.write("2025-01-03,28\n")

print("Solar energy data logged successfully.")
# Out:
# Solar energy data logged successfully.
