# %%
with open("load_demand.csv", "w") as file:
    file.write("Time,Load_kW\n")
    file.write("08:00,120\n")
    file.write("09:00,150\n")
    file.write("10:00,180\n")

print("Load demand data recorded successfully.")
# Out:
# Load demand data recorded successfully.
