# %%
with open("energy_audit.csv", "w") as file:
    file.write("Student_Name,Appliance,Power_W,Usage_Hours\n")
    file.write("Alice,Fan,75,6\n")
    file.write("Bob,Light,15,8\n")
    file.write("Charlie,AC,1500,4\n")

print("Student energy audit data stored successfully.")
# Out:
# Student energy audit data stored successfully.
