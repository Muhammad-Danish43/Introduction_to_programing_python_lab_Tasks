# %%
timer = 10

while timer >= 0:
    print("Timer:", timer)
    timer -= 1

print("Test Running")
# Out:
# Timer: 10
# Timer: 9
# Timer: 8
# Timer: 7
# Timer: 6
# Timer: 5
# Timer: 4
# Timer: 3
# Timer: 2
# Timer: 1
# Timer: 0
# Test Running
