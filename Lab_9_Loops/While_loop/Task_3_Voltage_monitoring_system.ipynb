# %%
voltage = -1  # initial value

while voltage != 0:
    voltage = int(input("Enter voltage (0 to stop): "))
    if voltage != 0:
        print("Voltage entered:", voltage)

print("System turned off")
# Out:
# Voltage entered: 3
# Voltage entered: 2
# Voltage entered: 5
# Voltage entered: 7
# Voltage entered: 8
# Voltage entered: 9
# Voltage entered: 9
# System turned off
