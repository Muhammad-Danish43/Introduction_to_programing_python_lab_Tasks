# %%
# List of resistor values in ohms
resistors = [100, 220, 330, 470, 1000]

# Print each resistance value
for r in resistors:
    print("Resistance:", r, "ohms")
# Out:
# Resistance: 100 ohms
# Resistance: 220 ohms
# Resistance: 330 ohms
# Resistance: 470 ohms
# Resistance: 1000 ohms
