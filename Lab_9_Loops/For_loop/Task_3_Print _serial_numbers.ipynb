# %%
# Print numbers from 1 to 10
for serial in range(1, 11):
    print("Instrument Serial Number:", serial)
# Out:
# Instrument Serial Number: 1
# Instrument Serial Number: 2
# Instrument Serial Number: 3
# Instrument Serial Number: 4
# Instrument Serial Number: 5
# Instrument Serial Number: 6
# Instrument Serial Number: 7
# Instrument Serial Number: 8
# Instrument Serial Number: 9
# Instrument Serial Number: 10
