# %%
# List of current readings in amperes
currents = [1, 2, 3, 4, 5]

for I in currents:
    print("Current:", I, "A, I²:", I * I)
# Out:
# Current: 1 A, I²: 1
# Current: 2 A, I²: 4
# Current: 3 A, I²: 9
# Current: 4 A, I²: 16
# Current: 5 A, I²: 25
