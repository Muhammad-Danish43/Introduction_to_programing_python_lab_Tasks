# %%
file = open("current.txt", "r")

for line in file:
    current = float(line)

    if current < 5:
        print(current, "A : Safe")
    elif current < 10:
        print(current, "A : Warning")
    else:
        print(current, "A : Overload")

file.close()
# Out:
# 78.0 A : Overload
# 78.0 A : Overload
# 90.0 A : Overload
# 1.0 A : Safe
# 3.0 A : Safe
# 5.0 A : Warning
