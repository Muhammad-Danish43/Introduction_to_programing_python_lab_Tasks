# %%
file = open("score.txt", "r")

for line in file:
    marks = int(line)

    if marks >= 50:
        print(marks, "Pass")
    else:
        print(marks, "Fail")

file.close()
# Out:
# 10 Fail
# 20 Fail
# 30 Fail
# 40 Fail
# 50 Pass
# 60 Pass
# 100 Pass
