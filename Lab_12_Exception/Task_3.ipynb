# %%
# Step 1: Run This Code
numbers = [10, 20, 30]
print(numbers[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Step 1: Run This Code
#       2 numbers = [10, 20, 30]
# ----> 3 print(numbers[5])
#
# IndexError: list index out of range

# %%
# Step 2: Fix the Code
numbers = [10, 20, 30]

try:
    print(numbers[5])
except IndexError:
    print("Index Error: The index you are trying to access is out of range.")
# Out:
# Index Error: The index you are trying to access is out of range.
