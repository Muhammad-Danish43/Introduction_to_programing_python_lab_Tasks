# %%
# Step 1: Run This Code
a = 10
b = "5"
result = a + b
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 a = 10
#       3 b = "5"
# ----> 4 result = a + b
#       5 print(result)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Step 2: Fix the Code
a = 10
b = "5"

try:
    result = a + b
    print(result)
except TypeError:
    print("Type Error: Cannot add an integer and a string. Please convert data types.")
# Out:
# Type Error: Cannot add an integer and a string. Please convert data types.
