# %%
def parallel(resistances: list) -> float:
    """
    Calculates parallel resistance.
    """
    total = 0
    for r in resistances:
        total += 1 / r
    return 1 / total

print(parallel([10, 20, 30]))
print(parallel.__annotations__)
# Out:
# 5.454545454545454
# {'resistances': <class 'list'>, 'return': <class 'float'>}
