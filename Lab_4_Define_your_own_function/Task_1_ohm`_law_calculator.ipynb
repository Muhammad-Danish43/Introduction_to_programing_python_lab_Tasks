# %%
def voltage(I=1, R=1):
    return I * R

# Positional
print(voltage(2, 5))
# Keyword
print(voltage(I=3, R=10))
# Default Arguments
print(voltage())
# Mixed Arguments
print(voltage(5, R=4))
# Out:
# 10
# 30
# 1
# 20
