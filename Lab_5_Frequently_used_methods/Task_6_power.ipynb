# %%
# using pow()
currents = [2, 3, 4]
print("Squares of current values:")
for i in currents:
    print("Current:", i, "A, Square:", pow(i, 2))
# Out:
# Squares of current values:
# Current: 2 A, Square: 4
# Current: 3 A, Square: 9
# Current: 4 A, Square: 16
