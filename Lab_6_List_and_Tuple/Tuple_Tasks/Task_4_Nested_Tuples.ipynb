# %%
data = ("UserA", (2023, 9, 15), ["task1", "task2"])

date = data[1]
print(date[0], date[1], date[2])

tasks = data[2]
tasks.append("task3")

print(data)
# Out:
# 2023 9 15
# ('UserA', (2023, 9, 15), ['task1', 'task2', 'task3'])

# %% [markdown]
# **What we did:**
#
# We accessed a tuple inside another tuple.
#
# We modified a list inside a tuple.
#
# This is possible because lists are mutable, even inside tuples.
