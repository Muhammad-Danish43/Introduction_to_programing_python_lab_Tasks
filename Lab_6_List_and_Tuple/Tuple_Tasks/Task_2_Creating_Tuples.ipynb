# %%
single = (5,)
print(type(single))

not_tuple = (5)
print(type(not_tuple))

t = tuple(range(5))
print(t)
# Out:
# <class 'tuple'>
# <class 'int'>
# (0, 1, 2, 3, 4)

# %% [markdown]
# **What we did**:
#
# We learned that a comma is required for a single-element tuple.
#
# Without a comma, Python treats it as an integer.
